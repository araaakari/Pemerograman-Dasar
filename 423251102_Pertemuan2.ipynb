# %% [markdown]
# <a href="https://colab.research.google.com/github/araaakari/Pemerograman-Dasar/blob/main/423251102_Pertemuan2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Jawaban Latihan 1
tegangan_panel = 18             # volt
arus_panel = 6                  # ampere
jenis_sel = "Monocrystalline"

print (tegangan_panel, arus_panel, jenis_sel)



# Jawaban Latihan 2
jumlah_resistor = 22            # int
nilai_kapasitor = 2.4           # float
dioda_menyala = True            # bool
nama_komponen = "Transistor"    # str

print(jumlah_resistor, type(jumlah_resistor))
print(nilai_kapasitor, type(nilai_kapasitor))
print(dioda_menyala, type(dioda_menyala))
print(nama_komponen, type(nama_komponen))



# Jawaban Latihan 3
nama_unit = "PLTS Nunukan"       # str
jumlah_panel = 240               # int
tegangan_keluaran = 48.5         # float
sedang_beroperasi = True         # bool

print(nama_unit, type(nama_unit))
print(jumlah_panel, type(jumlah_panel))
print(tegangan_keluaran, type(tegangan_keluaran))
print(sedang_beroperasi, type(sedang_beroperasi))



# Jawaban Latihan 4
tegangan_harian = [217.5, 219.0, 220.3, 218.7, 221.1, 216.9]

# A. Cetak pembacaan pertama dan terakhir memakai indeks
print("Pertama:", tegangan_harian[0])
print("Terakhir:", tegangan_harian[-1])

# B. Tambahkan satu pembacaan baru 222.0 dengan append()
tegangan_harian.append(222.0)

# c. cetak jumlah total data dengan len()
print("Jumlah total data:", len(tegangan_harian))



# Jawaban Latihan 5

# Dictionary spesifikasi sebuah motor listrik
motor = {
    "nama": "Motor Induksi 3 Fasa",
    "daya_kW": 5.7,
    "tegangan_V": 400,
    "rpm": 1470
}

# Cetak salah satu nilai lewat key-nya
print("RPM sebelum diubah:", motor["rpm"])

# Lalu ubah nilai rpm (pakai =)
motor["rpm"] = 1500

# cetak ulang seluruh dictionary
print(motor)



# Jawaban Latihan 6
pembangkit = [
    {"nama": "Unit-1", "kapasitas_MW": 100, "status": "operasi"},
    {"nama": "Unit-2", "kapasitas_MW": 150, "status": "operasi"},
    {"nama": "Unit-3", "kapasitas_MW": 80,  "status": "pemeliharaan"},
]

# Cetak nama unit kedua
print("Unit kedua:", pembangkit[1]["nama"])

# Ubah status salah satu unit
pembangkit[2]["status"] = "operasi"

# Tambahkan satu unit baru ke list dengan append()
pembangkit.append({"nama": "Unit-4", "kapasitas_MW": 120, "status": "operasi"})

# Cetak seluruh data
for unit in pembangkit:
    print(unit)
# Out:
# 18 6 Monocrystalline
# 22 <class 'int'>
# 2.4 <class 'float'>
# True <class 'bool'>
# Transistor <class 'str'>
# PLTS Nunukan <class 'str'>
# 240 <class 'int'>
# 48.5 <class 'float'>
# True <class 'bool'>
# Pertama: 217.5
# Terakhir: 216.9
# Jumlah total data: 7
# RPM sebelum diubah: 1470
# {'nama': 'Motor Induksi 3 Fasa', 'daya_kW': 5.7, 'tegangan_V': 400, 'rpm': 1500}
# Unit kedua: Unit-2
# {'nama': 'Unit-1', 'kapasitas_MW': 100, 'status': 'operasi'}
# {'nama': 'Unit-2', 'kapasitas_MW': 150, 'status': 'operasi'}
# {'nama': 'Unit-3', 'kapasitas_MW': 80, 'status': 'operasi'}
# {'nama': 'Unit-4', 'kapasitas_MW': 120, 'status': 'operasi'}
